# %%
### Contrast Group
import numpy as np
import matplotlib.pyplot as plt
from Methods import stimuli, file_process
##############################
CL_OL_CL_rig1_path = "/Users/haotianli/Code/EngertLab/Data/CL_OL_CL/stimulus_CL_OL_CL_savingmoreinfo_195s_rig1"
CL_OL_CL_rig1_data_paths, CL_OL_CL_rig1_HT_data_paths = file_process.extract_from_stimuli(CL_OL_CL_rig1_path)
stimuli_CL_OL_CL_rig1 = stimuli(CL_OL_CL_rig1_data_paths, CL_OL_CL_rig1_HT_data_paths)

CL_OL_CL_rig1_HT_data_paths_struggle, time_axes, avg_power_rig1 = stimuli_CL_OL_CL_rig1.struggle_detection(threshold=70, mode="fish")


##############################
CL_OL_CL_rig2_path = "/Users/haotianli/Code/EngertLab/Data/CL_OL_CL/stimulus_CL_OL_CL_savingmoreinfo_195s_rig2"
CL_OL_CL_rig2_data_paths, CL_OL_CL_rig2_HT_data_paths = file_process.extract_from_stimuli(CL_OL_CL_rig2_path)
stimuli_CL_OL_CL_rig2 = stimuli(CL_OL_CL_rig2_data_paths, CL_OL_CL_rig2_HT_data_paths)

CL_OL_CL_rig2_HT_data_paths_struggle, time_axes, avg_power_rig2 = stimuli_CL_OL_CL_rig2.struggle_detection(threshold=70, mode="fish")
